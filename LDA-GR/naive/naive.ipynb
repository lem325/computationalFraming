# %%
# [TODO] create conda virtual environment for package management
import os
os.chdir(os.environ['PROJECT_DIR'])

import pandas as pd
import pickle
import numpy as np
from datasets import load_dataset # hugging face datasets

from tqdm import tqdm
from p_tqdm import p_map # multiprocessing tqdm
from multiprocessing import Pool

import matplotlib.pyplot as plt
from graphviz import Source # graphing dependency tree

# [TODO] determine when is causing kernel restart from gensim
import gensim.parsing.preprocessing as gsp
import gensim.corpora as corpora
from gensim import utils
from gensim.models.coherencemodel import CoherenceModel

import stanza # stanford corenlp
try:
    corenlp = stanza.Pipeline('en', processors="tokenize,mwt,pos,lemma,depparse", verbose=False, use_gpu=False)
except:
    stanza.download('en') # download corenlp neural model
    corenlp = stanza.Pipeline('en', processors="tokenize,mwt,pos,lemma,depparse", verbose=False, use_gpu=False)

import nltk
from nltk import tokenize
try:
    nltk.corpus.stopwords.words('english')
except LookupError:
    nltk.download('stopwords') # download nltk stopwords

from lda.LDAMallet import LdaMallet # gensim LDA (gibbs sampling) mallet wrapper

# %%
# preprocess dataset using gensim filters
FILTERS = [
    gsp.strip_tags,
    gsp.strip_punctuation, 
    gsp.strip_multiple_whitespaces,
    gsp.strip_numeric,
    gsp.strip_short
]

# use nltk stopwords
STOP_WORDS = nltk.corpus.stopwords.words('english')

# %%
def _get_word_reln_pairs(doc: any, stop_words: list[str] = STOP_WORDS) -> list[tuple]:
    '''Loop through sentences and words in sentences to get dependency relationships'''
    
    valid_word = lambda word: not word in stop_words and word.isalpha() and len(word) > 2
    
    pairs = []
    for sent in doc.sentences:
        # since IDs can be two idxs: 1-2 we need to create a hashmap to access ids
        tokens = {
            str(word.id):word 
            for word in sent.words
        }
        for word in sent.words:
            word_text = utils.to_unicode(word.text.lower())
            
            # don't include root of sentence or non valid words
            if not word.head or not valid_word(word_text):
                continue
            
            # append both dep and gov of dependency relationship
            head = tokens[str(word.head)]
            pairs.extend(
                [(word_text, f'{word.deprel}.dep'), (head.text, f'{word.deprel}.gov')]
            )
            
    return pairs
            

def _process_pairs(pairs: list[tuple], stop_words: list[str] = STOP_WORDS) -> list[tuple]:
    '''Remove words that are stop words, non-alphabetic, and less than 3 characters long'''
    
    valid_word = lambda word: not word in stop_words and word.isalpha() and len(word) > 2
    
    processed_pairs = []
    for word, reln in pairs:
        # [TODO] unicode and lower full documents instead of each word for increase efficiency
        processed_word = utils.to_unicode(word.lower())
        if valid_word(processed_word):
            processed_pairs.append((processed_word, reln))
    
    return processed_pairs

def _concatenate_pairs(pairs: list[tuple], sep: str = "%") -> list[str]:
    '''Join dependency relational pairs into single strings using seperator'''
    
    join_tuple = lambda pair: sep.join(pair)
    strs = list(map(join_tuple, pairs))
    
    return strs

def coherence_optimization(tokens: list[any], id2word: dict, corpus: list[any], topics_range: iter) -> tuple[list[any], list[any]]:
    '''
    Description
        Perform coherence optimization on LDA Mallet model. This finds the model that has the best coherence
        in relation to number of topics. Essentially finds the best number of topics for a given corpus.
    
    Params
        tokens: tokenized documents
        id2word: a Gensim dictionary mapping of id to word.
        corpus: list of documents in bag of word (BoW) format
    
    Returns
        model_list -> list[LdaMallet]
        coherence_values -> list[float]
    '''
    
    model_list, coherence_values = [], []
    for n_topics in tqdm(topics_range):
        model = LdaMallet(os.environ['MALLET_DIR'], corpus=corpus, num_topics=n_topics, id2word=id2word)
        coherence_model = CoherenceModel(model=model, texts=tokens, coherence='c_npmi')

        model_list.append(model)
        coherence_values.append(coherence_model.get_coherence())
    
    return model_list, coherence_values

def get_tokens(text: str) -> list[str]:
    '''Obtain concatenated dependency relational pairs of text'''

    doc = corenlp(text)
    word_reln_pairs = _get_word_reln_pairs(doc)
    processed_pairs = _process_pairs(word_reln_pairs)
    word_reln_strs = _concatenate_pairs(processed_pairs, sep="?")
    
    return word_reln_strs

def get_topics(model: any, n_topics: int) -> dict:
    '''Returns dictionary of topics'''
    
    topics_dict = dict(model.print_topics(num_topics=n_topics))
    topics_dict = {int(k):v for k,v in topics_dict.items()}
    
    return topics_dict

def get_doc_top_matrix(model: any, n_topics: int) -> list[any]:
    '''Sort document topic matrix and add probability of 0 for topics that aren't included in documents'''
    
    doc_top_matrix = [*model.load_document_topics()]
    
    new_doc_top_matrix = []
    for doc_top in doc_top_matrix:
        _dict = dict(doc_top)
        for key in range(n_topics):
            if key not in _dict:
                _dict[key] = 0
        new_doc_top_matrix.append(list(_dict.items()))

    doc_top_matrix = [sorted(arr) for arr in new_doc_top_matrix]
    
    return doc_top_matrix

# %%
# # load dataset
# newsgroup_dataset = load_dataset('newsgroup', '18828_alt.atheism')
# atheism_texts = newsgroup_dataset['train']['text']

# https://huggingface.co/datasets/cnn_dailymail/viewer/2.0.0/
# load dataset
dailymail = load_dataset('cnn_dailymail', '2.0.0')
texts = dailymail['train']['article'][:2000]
# Out:
# Found cached dataset cnn_dailymail (/Users/chasemattingly/.cache/huggingface/datasets/cnn_dailymail/2.0.0/2.0.0/1b3c71476f6d152c31c1730e83ccb08bcf23e348233f4fcc11e182248e6bf7de)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# process texts 
tokens = p_map(get_tokens, texts)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
id2word = corpora.Dictionary(tokens)
corpus = list(map(lambda x: id2word.doc2bow(x), tokens))

# %%
model = LdaMallet(os.environ['MALLET_DIR'], corpus=corpus, num_topics=5, id2word=id2word)
# Out:
# Coded LDA: 5 topics, 3 topic bits, 111 topic mask
# max tokens: 1754
# total tokens: 1170980
# <10> LL/token: -12.37567
# <20> LL/token: -12.00686
# <30> LL/token: -11.81946
# <40> LL/token: -11.72619
#
# 0	10	would?aux.dep said?ccomp.gov said?nsubj.gov new?amod.dep obama?nsubj.dep president?flat.gov also?advmod.dep democratic?amod.dep national?amod.dep president?nsubj.dep obama?flat.dep presidential?amod.dep going?xcomp.gov political?amod.dep white?amod.dep former?amod.dep john?flat.gov american?amod.dep could?aux.dep
# 1	10	said?nsubj.gov said?ccomp.gov united?amod.dep two?nummod.dep according?case.dep officials?nsubj.dep said?obl.gov president?flat.gov also?advmod.dep said?parataxis.dep international?amod.dep states?amod.gov minister?amod.gov minister?flat.gov military?amod.dep security?compound.dep iraqi?amod.dep government?amod.gov report?obl.dep
# 2	10	says?ccomp.gov says?nsubj.gov people?nsubj.dep also?advmod.dep years?obl.dep would?aux.dep one?nummod.dep one?nmod.gov say?ccomp.gov could?aux.dep one?nsubj.dep many?amod.dep said?ccomp.gov world?nmod.dep year?obl:tmod.dep take?obj.gov people?nmod.dep united?amod.dep new?amod.dep
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov police?nsubj.dep old?amod.dep could?aux.dep according?case.dep also?advmod.dep two?nummod.dep three?nummod.dep authorities?nsubj.dep found?obl.gov watch?obj.gov taken?obl.gov found?obj.gov would?aux.dep
# 4	10	first?amod.dep like?case.dep really?advmod.dep back?advmod.dep one?nmod.gov think?ccomp.gov still?advmod.dep good?amod.dep never?advmod.dep says?nsubj.gov two?nummod.dep second?amod.dep people?nsubj.dep best?amod.dep one?nummod.dep even?advmod.dep always?advmod.dep new?amod.dep well?advmod.dep
#
# <50> LL/token: -11.67075
# <60> LL/token: -11.63551
# <70> LL/token: -11.60877
# <80> LL/token: -11.59103
# <90> LL/token: -11.57606
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep obama?nsubj.dep president?flat.gov new?amod.dep democratic?amod.dep national?amod.dep president?nsubj.dep obama?flat.dep presidential?amod.dep also?advmod.dep john?flat.gov american?amod.dep white?amod.dep former?amod.dep political?amod.dep said?obl.gov first?amod.dep
# 1	10	said?nsubj.gov said?ccomp.gov united?amod.dep two?nummod.dep officials?nsubj.dep also?advmod.dep president?flat.gov according?case.dep states?amod.gov minister?amod.gov said?obl.gov said?parataxis.dep minister?flat.gov military?amod.dep international?amod.dep security?compound.dep iraqi?amod.dep government?amod.gov last?amod.dep
# 2	10	says?ccomp.gov says?nsubj.gov would?aux.dep people?nsubj.dep new?amod.dep could?aux.dep years?obl.dep one?nummod.dep one?nmod.gov many?amod.dep like?case.dep even?advmod.dep still?advmod.dep people?nmod.dep year?amod.gov one?nsubj.dep also?advmod.dep able?xcomp.gov world?nmod.dep
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep according?case.dep police?nsubj.dep authorities?nsubj.dep old?amod.dep also?advmod.dep watch?obj.gov three?nummod.dep could?aux.dep found?obl.gov police?compound.dep said?obl.gov found?obj.gov
# 4	10	first?amod.dep really?advmod.dep like?case.dep think?ccomp.gov also?advmod.dep two?nummod.dep best?amod.dep back?advmod.dep always?advmod.dep one?nmod.gov second?amod.dep new?amod.dep one?nummod.dep three?nummod.dep good?amod.dep lot?nmod.gov still?advmod.dep never?advmod.dep old?amod.dep
#
# <100> LL/token: -11.56435
# <110> LL/token: -11.5542
# <120> LL/token: -11.54709
# <130> LL/token: -11.54121
# <140> LL/token: -11.53764
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep also?advmod.dep national?amod.dep president?nsubj.dep american?amod.dep obama?flat.dep former?amod.dep presidential?amod.dep political?amod.dep john?flat.gov white?amod.dep said?obl.gov watch?obj.gov
# 1	10	said?ccomp.gov said?nsubj.gov two?nummod.dep united?amod.dep also?advmod.dep officials?nsubj.dep according?case.dep minister?amod.gov president?flat.gov minister?flat.gov military?amod.dep states?amod.gov said?obl.gov international?amod.dep security?compound.dep said?parataxis.dep iraqi?amod.dep government?amod.gov last?amod.dep
# 2	10	says?ccomp.gov says?nsubj.gov new?amod.dep people?nsubj.dep would?aux.dep years?obl.dep one?nummod.dep like?case.dep could?aux.dep many?amod.dep even?advmod.dep million?nummod.dep one?nmod.gov still?advmod.dep year?obl:tmod.dep one?nsubj.dep able?xcomp.gov may?aux.dep people?nmod.dep
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov according?case.dep police?nsubj.dep two?nummod.dep also?advmod.dep authorities?nsubj.dep watch?obj.gov old?amod.dep could?aux.dep three?nummod.dep found?obl.gov police?compound.dep said?obl.gov found?obj.gov
# 4	10	first?amod.dep really?advmod.dep also?advmod.dep like?case.dep two?nummod.dep think?ccomp.gov back?advmod.dep one?nmod.gov best?amod.dep three?nummod.dep second?amod.dep always?advmod.dep never?advmod.dep one?nummod.dep good?amod.dep time?amod.gov last?amod.dep great?amod.dep old?amod.dep
#
# <150> LL/token: -11.53465
# <160> LL/token: -11.5319
# <170> LL/token: -11.52923
# <180> LL/token: -11.52683
# <190> LL/token: -11.52488
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep president?nsubj.dep national?amod.dep also?advmod.dep american?amod.dep obama?flat.dep presidential?amod.dep said?obl.gov former?amod.dep political?amod.dep white?amod.dep john?flat.gov watch?obj.gov
# 1	10	said?nsubj.gov said?ccomp.gov united?amod.dep two?nummod.dep also?advmod.dep minister?amod.gov minister?flat.gov military?amod.dep according?case.dep officials?nsubj.dep president?flat.gov security?compound.dep states?amod.gov iraqi?amod.dep government?amod.gov said?parataxis.dep international?amod.dep government?nsubj.dep last?amod.dep
# 2	10	says?ccomp.gov says?nsubj.gov new?amod.dep would?aux.dep could?aux.dep people?nsubj.dep like?case.dep million?nummod.dep years?obl.dep one?nmod.gov many?amod.dep even?advmod.dep one?nummod.dep may?aux.dep still?advmod.dep one?nsubj.dep year?obl:tmod.dep make?obj.gov years?amod.gov
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep also?advmod.dep authorities?nsubj.dep could?aux.dep watch?obj.gov found?obl.gov said?obl.gov old?amod.dep police?compound.dep three?nummod.dep taken?obl.gov
# 4	10	first?amod.dep really?advmod.dep think?ccomp.gov two?nummod.dep also?advmod.dep like?case.dep back?advmod.dep best?amod.dep always?advmod.dep second?amod.dep one?nummod.dep one?nmod.gov time?amod.gov last?amod.dep three?nummod.dep old?amod.dep never?advmod.dep great?amod.dep good?amod.dep
#
# <200> LL/token: -11.52364
# <210> LL/token: -11.52305
# <220> LL/token: -11.52132
# <230> LL/token: -11.52068
# <240> LL/token: -11.52146
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep president?nsubj.dep american?amod.dep said?obl.gov national?amod.dep former?amod.dep also?advmod.dep obama?flat.dep presidential?amod.dep political?amod.dep white?amod.dep john?flat.gov president?amod.gov
# 1	10	said?nsubj.gov said?ccomp.gov two?nummod.dep united?amod.dep according?case.dep minister?amod.gov also?advmod.dep minister?flat.gov military?amod.dep security?compound.dep president?flat.gov officials?nsubj.dep iraqi?amod.dep government?amod.gov international?amod.dep states?amod.gov said?parataxis.dep iraq?nmod.dep last?amod.dep
# 2	10	says?ccomp.gov says?nsubj.gov new?amod.dep would?aux.dep million?nummod.dep could?aux.dep like?case.dep people?nsubj.dep even?advmod.dep may?aux.dep many?amod.dep years?obl.dep one?nmod.gov also?advmod.dep one?nummod.dep one?nsubj.dep still?advmod.dep year?amod.gov years?amod.gov
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep watch?obj.gov also?advmod.dep authorities?nsubj.dep three?nummod.dep could?aux.dep found?obl.gov police?compound.dep old?amod.dep said?obl.gov taken?obl.gov
# 4	10	first?amod.dep really?advmod.dep like?case.dep think?ccomp.gov one?nummod.dep back?advmod.dep also?advmod.dep two?nummod.dep best?amod.dep one?nmod.gov old?amod.dep never?advmod.dep last?amod.dep three?nummod.dep second?amod.dep would?aux.dep always?advmod.dep good?amod.dep great?amod.dep
#
# <250> LL/token: -11.51967
# <260> LL/token: -11.51798
# <270> LL/token: -11.51625
# <280> LL/token: -11.51479
# <290> LL/token: -11.51556
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep president?nsubj.dep former?amod.dep also?advmod.dep political?amod.dep american?amod.dep obama?flat.dep presidential?amod.dep said?obl.gov john?flat.gov white?amod.dep national?amod.dep president?amod.gov
# 1	10	said?ccomp.gov said?nsubj.gov united?amod.dep two?nummod.dep minister?amod.gov according?case.dep minister?flat.gov military?amod.dep also?advmod.dep president?flat.gov security?compound.dep iraqi?amod.dep international?amod.dep officials?nsubj.dep states?amod.gov government?amod.gov said?parataxis.dep last?amod.dep government?nsubj.dep
# 2	10	says?ccomp.gov says?nsubj.gov new?amod.dep million?nummod.dep would?aux.dep like?case.dep could?aux.dep even?advmod.dep one?nummod.dep may?aux.dep many?amod.dep years?obl.dep people?nsubj.dep one?nmod.gov year?obl:tmod.dep also?advmod.dep world?nmod.dep make?obj.gov years?amod.gov
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep also?advmod.dep authorities?nsubj.dep watch?obj.gov said?obl.gov could?aux.dep found?obl.gov three?nummod.dep police?compound.dep old?amod.dep said?advcl.gov
# 4	10	first?amod.dep really?advmod.dep like?case.dep think?ccomp.gov also?advmod.dep back?advmod.dep would?aux.dep one?nmod.gov two?nummod.dep best?amod.dep old?amod.dep never?advmod.dep one?nummod.dep three?nummod.dep last?amod.dep new?amod.dep good?amod.dep still?advmod.dep want?xcomp.gov
#
# <300> LL/token: -11.51439
# <310> LL/token: -11.51309
# <320> LL/token: -11.51278
# <330> LL/token: -11.51257
# <340> LL/token: -11.51387
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep president?nsubj.dep democratic?amod.dep american?amod.dep also?advmod.dep obama?flat.dep former?amod.dep political?amod.dep presidential?amod.dep said?obl.gov national?amod.dep john?flat.gov white?amod.dep president?amod.gov
# 1	10	said?ccomp.gov said?nsubj.gov two?nummod.dep united?amod.dep minister?amod.gov also?advmod.dep minister?flat.gov military?amod.dep according?case.dep security?compound.dep iraqi?amod.dep international?amod.dep government?amod.gov states?amod.gov president?flat.gov officials?nsubj.dep said?obl.gov last?amod.dep government?nsubj.dep
# 2	10	says?ccomp.gov says?nsubj.gov new?amod.dep would?aux.dep million?nummod.dep could?aux.dep may?aux.dep like?case.dep people?nsubj.dep even?advmod.dep also?advmod.dep many?amod.dep years?obl.dep one?nmod.gov make?obj.gov one?nummod.dep world?nmod.dep years?amod.gov able?xcomp.gov
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep according?case.dep police?nsubj.dep authorities?nsubj.dep watch?obj.gov also?advmod.dep three?nummod.dep found?obl.gov police?compound.dep old?amod.dep could?aux.dep said?obl.gov department?compound.gov
# 4	10	first?amod.dep really?advmod.dep like?case.dep one?nummod.dep think?ccomp.gov one?nmod.gov two?nummod.dep would?aux.dep best?amod.dep also?advmod.dep back?advmod.dep never?advmod.dep second?amod.dep old?amod.dep three?nummod.dep still?advmod.dep great?amod.dep time?amod.gov last?amod.dep
#
# <350> LL/token: -11.51152
# <360> LL/token: -11.512
# <370> LL/token: -11.51239
# <380> LL/token: -11.51144
# <390> LL/token: -11.51073
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep president?nsubj.dep democratic?amod.dep also?advmod.dep american?amod.dep former?amod.dep obama?flat.dep political?amod.dep presidential?amod.dep said?obl.gov national?amod.dep white?amod.dep john?flat.gov president?amod.gov
# 1	10	said?nsubj.gov said?ccomp.gov united?amod.dep two?nummod.dep minister?amod.gov minister?flat.gov military?amod.dep international?amod.dep according?case.dep security?compound.dep also?advmod.dep iraqi?amod.dep president?flat.gov states?amod.gov officials?nsubj.dep government?amod.gov government?nsubj.dep last?amod.dep said?obl.gov
# 2	10	says?nsubj.gov says?ccomp.gov new?amod.dep million?nummod.dep could?aux.dep people?nsubj.dep would?aux.dep even?advmod.dep like?case.dep also?advmod.dep may?aux.dep one?nummod.dep years?obl.dep one?nmod.gov many?amod.dep make?obj.gov years?amod.gov year?obl:tmod.dep one?nsubj.dep
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep according?case.dep police?nsubj.dep authorities?nsubj.dep watch?obj.gov also?advmod.dep three?nummod.dep said?obl.gov found?obl.gov police?compound.dep could?aux.dep old?amod.dep said?advcl.gov
# 4	10	first?amod.dep really?advmod.dep like?case.dep think?ccomp.gov one?nmod.gov one?nummod.dep back?advmod.dep two?nummod.dep also?advmod.dep never?advmod.dep would?aux.dep old?amod.dep best?amod.dep still?advmod.dep second?amod.dep last?amod.dep always?advmod.dep good?amod.dep ever?advmod.dep
#
# <400> LL/token: -11.50904
# <410> LL/token: -11.50974
# <420> LL/token: -11.51044
# <430> LL/token: -11.51145
# <440> LL/token: -11.51045
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep president?nsubj.dep democratic?amod.dep also?advmod.dep american?amod.dep former?amod.dep obama?flat.dep political?amod.dep said?obl.gov presidential?amod.dep national?amod.dep white?amod.dep president?amod.gov john?flat.gov
# 1	10	said?ccomp.gov said?nsubj.gov two?nummod.dep united?amod.dep minister?amod.gov minister?flat.gov military?amod.dep also?advmod.dep security?compound.dep international?amod.dep according?case.dep iraqi?amod.dep states?amod.gov government?amod.gov last?amod.dep president?flat.gov officials?nsubj.dep said?obl.gov government?nsubj.dep
# 2	10	says?nsubj.gov says?ccomp.gov new?amod.dep would?aux.dep million?nummod.dep also?advmod.dep may?aux.dep like?case.dep even?advmod.dep people?nsubj.dep could?aux.dep one?nummod.dep one?nmod.gov years?obl.dep many?amod.dep make?obj.gov years?amod.gov year?obl:tmod.dep world?nmod.dep
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov according?case.dep two?nummod.dep police?nsubj.dep authorities?nsubj.dep also?advmod.dep watch?obj.gov three?nummod.dep could?aux.dep found?obl.gov said?obl.gov police?compound.dep old?amod.dep said?advcl.gov
# 4	10	first?amod.dep really?advmod.dep like?case.dep think?ccomp.gov would?aux.dep one?nummod.dep one?nmod.gov never?advmod.dep two?nummod.dep back?advmod.dep old?amod.dep best?amod.dep three?nummod.dep still?advmod.dep also?advmod.dep last?amod.dep could?aux.dep second?amod.dep good?amod.dep
#
# <450> LL/token: -11.51118
# <460> LL/token: -11.51105
# <470> LL/token: -11.50957
# <480> LL/token: -11.51187
# <490> LL/token: -11.51133
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep american?amod.dep president?nsubj.dep former?amod.dep obama?flat.dep said?obl.gov also?advmod.dep political?amod.dep presidential?amod.dep white?amod.dep national?amod.dep president?amod.gov house?amod.gov
# 1	10	said?nsubj.gov said?ccomp.gov united?amod.dep two?nummod.dep also?advmod.dep minister?amod.gov minister?flat.gov military?amod.dep international?amod.dep security?compound.dep according?case.dep president?flat.gov iraqi?amod.dep states?amod.gov officials?nsubj.dep government?amod.gov last?amod.dep said?obl.gov government?nsubj.dep
# 2	10	says?nsubj.gov says?ccomp.gov new?amod.dep million?nummod.dep would?aux.dep could?aux.dep also?advmod.dep may?aux.dep like?case.dep one?nummod.dep people?nsubj.dep one?nmod.gov even?advmod.dep years?obl.dep make?obj.gov many?amod.dep year?obl:tmod.dep years?amod.gov one?nsubj.dep
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep according?case.dep police?nsubj.dep watch?obj.gov authorities?nsubj.dep three?nummod.dep also?advmod.dep said?obl.gov found?obl.gov police?compound.dep could?aux.dep old?amod.dep said?advcl.gov
# 4	10	first?amod.dep like?case.dep really?advmod.dep think?ccomp.gov back?advmod.dep never?advmod.dep one?nmod.gov old?amod.dep would?aux.dep one?nummod.dep also?advmod.dep last?amod.dep says?ccomp.gov best?amod.dep two?nummod.dep still?advmod.dep always?advmod.dep good?amod.dep new?amod.dep
#
# <500> LL/token: -11.51011
# <510> LL/token: -11.50928
# <520> LL/token: -11.51031
# <530> LL/token: -11.50893
# <540> LL/token: -11.50951
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep president?nsubj.dep democratic?amod.dep american?amod.dep said?obl.gov former?amod.dep obama?flat.dep presidential?amod.dep also?advmod.dep political?amod.dep national?amod.dep white?amod.dep john?flat.gov president?amod.gov
# 1	10	said?nsubj.gov said?ccomp.gov united?amod.dep two?nummod.dep minister?amod.gov according?case.dep minister?flat.gov military?amod.dep also?advmod.dep security?compound.dep president?flat.gov international?amod.dep iraqi?amod.dep states?amod.gov government?amod.gov last?amod.dep officials?nsubj.dep said?obl.gov government?nsubj.dep
# 2	10	says?ccomp.gov says?nsubj.gov new?amod.dep million?nummod.dep also?advmod.dep like?case.dep would?aux.dep may?aux.dep one?nummod.dep could?aux.dep even?advmod.dep people?nsubj.dep many?amod.dep years?obl.dep one?nmod.gov make?obj.gov one?nsubj.dep united?amod.dep years?amod.gov
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep also?advmod.dep authorities?nsubj.dep watch?obj.gov three?nummod.dep found?obl.gov police?compound.dep old?amod.dep said?obl.gov could?aux.dep department?compound.gov
# 4	10	first?amod.dep really?advmod.dep like?case.dep back?advmod.dep think?ccomp.gov one?nmod.gov would?aux.dep still?advmod.dep one?nummod.dep two?nummod.dep says?ccomp.gov never?advmod.dep last?amod.dep also?advmod.dep best?amod.dep old?amod.dep could?aux.dep always?advmod.dep time?amod.gov
#
# <550> LL/token: -11.51085
# <560> LL/token: -11.51001
# <570> LL/token: -11.50966
# <580> LL/token: -11.5093
# <590> LL/token: -11.50969
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep president?nsubj.dep former?amod.dep american?amod.dep obama?flat.dep said?obl.gov presidential?amod.dep political?amod.dep also?advmod.dep national?amod.dep white?amod.dep president?amod.gov john?flat.gov
# 1	10	said?ccomp.gov said?nsubj.gov united?amod.dep two?nummod.dep minister?amod.gov also?advmod.dep minister?flat.gov military?amod.dep president?flat.gov security?compound.dep international?amod.dep iraqi?amod.dep according?case.dep government?amod.gov states?amod.gov officials?nsubj.dep said?obl.gov government?nsubj.dep last?amod.dep
# 2	10	says?nsubj.gov new?amod.dep says?ccomp.gov million?nummod.dep would?aux.dep could?aux.dep also?advmod.dep may?aux.dep people?nsubj.dep like?case.dep even?advmod.dep one?nummod.dep one?nmod.gov years?obl.dep make?obj.gov many?amod.dep high?amod.dep able?xcomp.gov money?obj.dep
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep according?case.dep police?nsubj.dep authorities?nsubj.dep watch?obj.gov also?advmod.dep three?nummod.dep police?compound.dep found?obl.gov could?aux.dep said?obl.gov old?amod.dep department?compound.gov
# 4	10	first?amod.dep like?case.dep really?advmod.dep says?ccomp.gov would?aux.dep think?ccomp.gov still?advmod.dep never?advmod.dep back?advmod.dep one?nmod.gov also?advmod.dep one?nummod.dep last?amod.dep best?amod.dep two?nummod.dep even?advmod.dep old?amod.dep says?nsubj.gov good?amod.dep
#
# <600> LL/token: -11.51052
# <610> LL/token: -11.50902
# <620> LL/token: -11.50904
# <630> LL/token: -11.51028
# <640> LL/token: -11.51088
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep president?nsubj.dep former?amod.dep national?amod.dep american?amod.dep obama?flat.dep also?advmod.dep said?obl.gov presidential?amod.dep political?amod.dep white?amod.dep john?flat.gov president?amod.gov
# 1	10	said?nsubj.gov said?ccomp.gov united?amod.dep two?nummod.dep minister?amod.gov minister?flat.gov military?amod.dep security?compound.dep states?amod.gov also?advmod.dep iraqi?amod.dep international?amod.dep government?amod.gov president?flat.gov according?case.dep last?amod.dep said?obl.gov government?nsubj.dep officials?nsubj.dep
# 2	10	says?ccomp.gov says?nsubj.gov new?amod.dep million?nummod.dep would?aux.dep also?advmod.dep may?aux.dep could?aux.dep even?advmod.dep people?nsubj.dep like?case.dep many?amod.dep one?nummod.dep years?obl.dep one?nmod.gov make?obj.gov high?amod.dep percent?nmod.gov system?compound.gov
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep also?advmod.dep authorities?nsubj.dep watch?obj.gov could?aux.dep three?nummod.dep said?obl.gov police?compound.dep found?obl.gov old?amod.dep said?advcl.gov
# 4	10	first?amod.dep like?case.dep really?advmod.dep says?ccomp.gov one?nmod.gov would?aux.dep think?ccomp.gov one?nummod.dep back?advmod.dep never?advmod.dep old?amod.dep still?advmod.dep also?advmod.dep two?nummod.dep best?amod.dep says?nsubj.gov last?amod.dep even?advmod.dep always?advmod.dep
#
# <650> LL/token: -11.51097
# <660> LL/token: -11.51147
# <670> LL/token: -11.5102
# <680> LL/token: -11.51072
# <690> LL/token: -11.51007
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep president?nsubj.dep former?amod.dep american?amod.dep obama?flat.dep presidential?amod.dep said?obl.gov political?amod.dep white?amod.dep national?amod.dep also?advmod.dep john?flat.gov president?amod.gov
# 1	10	said?ccomp.gov said?nsubj.gov united?amod.dep two?nummod.dep also?advmod.dep minister?amod.gov minister?flat.gov military?amod.dep president?flat.gov international?amod.dep security?compound.dep iraqi?amod.dep government?amod.gov states?amod.gov last?amod.dep said?obl.gov according?case.dep officials?nsubj.dep government?nsubj.dep
# 2	10	new?amod.dep says?nsubj.gov says?ccomp.gov million?nummod.dep also?advmod.dep would?aux.dep may?aux.dep could?aux.dep said?ccomp.gov one?nmod.gov people?nsubj.dep even?advmod.dep make?obj.gov like?case.dep one?nummod.dep many?amod.dep years?obl.dep high?amod.dep billion?nummod.dep
# 3	10	said?nsubj.gov said?ccomp.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep authorities?nsubj.dep watch?obj.gov also?advmod.dep could?aux.dep three?nummod.dep police?compound.dep found?obl.gov said?obl.gov old?amod.dep department?compound.gov
# 4	10	first?amod.dep like?case.dep really?advmod.dep says?ccomp.gov think?ccomp.gov would?aux.dep back?advmod.dep one?nummod.dep never?advmod.dep still?advmod.dep old?amod.dep one?nmod.gov last?amod.dep also?advmod.dep says?nsubj.gov best?amod.dep new?amod.dep even?advmod.dep second?amod.dep
#
# <700> LL/token: -11.51038
# <710> LL/token: -11.51102
# <720> LL/token: -11.51098
# <730> LL/token: -11.51112
# <740> LL/token: -11.51207
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep president?nsubj.dep democratic?amod.dep american?amod.dep former?amod.dep said?obl.gov obama?flat.dep presidential?amod.dep political?amod.dep white?amod.dep john?flat.gov national?amod.dep also?advmod.dep could?aux.dep
# 1	10	said?ccomp.gov said?nsubj.gov united?amod.dep two?nummod.dep also?advmod.dep minister?amod.gov president?flat.gov minister?flat.gov military?amod.dep international?amod.dep security?compound.dep iraqi?amod.dep government?amod.gov last?amod.dep states?amod.gov according?case.dep officials?nsubj.dep government?nsubj.dep said?obl.gov
# 2	10	new?amod.dep says?nsubj.gov million?nummod.dep says?ccomp.gov would?aux.dep also?advmod.dep could?aux.dep may?aux.dep said?ccomp.gov like?case.dep people?nsubj.dep one?nummod.dep many?amod.dep even?advmod.dep make?obj.gov one?nmod.gov united?amod.dep years?obl.dep billion?nummod.dep
# 3	10	said?nsubj.gov said?ccomp.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep authorities?nsubj.dep also?advmod.dep watch?obj.gov police?compound.dep three?nummod.dep said?obl.gov could?aux.dep said?advcl.gov found?obl.gov department?compound.gov
# 4	10	first?amod.dep like?case.dep says?ccomp.gov really?advmod.dep would?aux.dep think?ccomp.gov one?nmod.gov one?nummod.dep back?advmod.dep still?advmod.dep also?advmod.dep two?nummod.dep old?amod.dep last?amod.dep never?advmod.dep even?advmod.dep best?amod.dep says?nsubj.gov three?nummod.dep
#
# <750> LL/token: -11.51141
# <760> LL/token: -11.51207
# <770> LL/token: -11.51209
# <780> LL/token: -11.51061
# <790> LL/token: -11.51248
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep former?amod.dep also?advmod.dep president?nsubj.dep american?amod.dep said?obl.gov obama?flat.dep presidential?amod.dep white?amod.dep john?flat.gov political?amod.dep watch?obj.gov national?amod.dep
# 1	10	said?nsubj.gov said?ccomp.gov united?amod.dep two?nummod.dep minister?amod.gov also?advmod.dep minister?flat.gov military?amod.dep states?amod.gov president?flat.gov international?amod.dep security?compound.dep iraqi?amod.dep last?amod.dep government?amod.gov said?obl.gov according?case.dep officials?nsubj.dep government?nsubj.dep
# 2	10	new?amod.dep million?nummod.dep says?ccomp.gov says?nsubj.gov said?ccomp.gov also?advmod.dep would?aux.dep could?aux.dep may?aux.dep like?case.dep even?advmod.dep one?nummod.dep one?nmod.gov people?nsubj.dep make?obj.gov many?amod.dep years?obl.dep high?amod.dep billion?nummod.dep
# 3	10	said?nsubj.gov said?ccomp.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep authorities?nsubj.dep watch?obj.gov also?advmod.dep police?compound.dep could?aux.dep said?obl.gov found?obl.gov three?nummod.dep old?amod.dep said?obl:tmod.gov
# 4	10	first?amod.dep like?case.dep really?advmod.dep says?ccomp.gov back?advmod.dep would?aux.dep think?ccomp.gov one?nummod.dep one?nmod.gov never?advmod.dep best?amod.dep last?amod.dep says?nsubj.gov still?advmod.dep could?aux.dep even?advmod.dep also?advmod.dep two?nummod.dep old?amod.dep
#
# <800> LL/token: -11.51154
# <810> LL/token: -11.51214
# <820> LL/token: -11.51195
# <830> LL/token: -11.51101
# <840> LL/token: -11.5118
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep american?amod.dep president?nsubj.dep obama?flat.dep presidential?amod.dep former?amod.dep said?obl.gov white?amod.dep political?amod.dep also?advmod.dep john?flat.gov president?amod.gov watch?obj.gov
# 1	10	said?ccomp.gov said?nsubj.gov united?amod.dep two?nummod.dep also?advmod.dep minister?amod.gov minister?flat.gov military?amod.dep international?amod.dep last?amod.dep states?amod.gov security?compound.dep president?flat.gov iraqi?amod.dep government?amod.gov according?case.dep said?obl.gov government?nsubj.dep officials?nsubj.dep
# 2	10	new?amod.dep million?nummod.dep says?nsubj.gov says?ccomp.gov said?ccomp.gov also?advmod.dep could?aux.dep would?aux.dep may?aux.dep even?advmod.dep like?case.dep one?nmod.gov one?nummod.dep many?amod.dep people?nsubj.dep years?obl.dep high?amod.dep make?obj.gov said?nsubj.gov
# 3	10	said?nsubj.gov said?ccomp.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep watch?obj.gov authorities?nsubj.dep also?advmod.dep police?compound.dep said?obl.gov three?nummod.dep could?aux.dep found?obl.gov department?compound.gov said?obl:tmod.gov
# 4	10	first?amod.dep like?case.dep says?ccomp.gov really?advmod.dep would?aux.dep think?ccomp.gov back?advmod.dep one?nmod.gov never?advmod.dep one?nummod.dep says?nsubj.gov could?aux.dep two?nummod.dep still?advmod.dep also?advmod.dep best?amod.dep last?amod.dep old?amod.dep always?advmod.dep
#
# <850> LL/token: -11.512
# <860> LL/token: -11.51215
# <870> LL/token: -11.51154
# <880> LL/token: -11.51234
# <890> LL/token: -11.51129
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep president?nsubj.dep american?amod.dep obama?flat.dep former?amod.dep presidential?amod.dep said?obl.gov political?amod.dep white?amod.dep john?flat.gov also?advmod.dep national?amod.dep watch?obj.gov
# 1	10	said?ccomp.gov said?nsubj.gov united?amod.dep two?nummod.dep also?advmod.dep minister?amod.gov president?flat.gov international?amod.dep minister?flat.gov military?amod.dep security?compound.dep states?amod.gov iraqi?amod.dep government?amod.gov last?amod.dep according?case.dep said?obl.gov officials?nsubj.dep government?nsubj.dep
# 2	10	new?amod.dep million?nummod.dep says?ccomp.gov said?ccomp.gov says?nsubj.gov also?advmod.dep would?aux.dep may?aux.dep could?aux.dep like?case.dep one?nmod.gov even?advmod.dep many?amod.dep one?nummod.dep years?obl.dep people?nsubj.dep make?obj.gov billion?nummod.dep united?amod.dep
# 3	10	said?nsubj.gov said?ccomp.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep authorities?nsubj.dep watch?obj.gov also?advmod.dep said?obl.gov could?aux.dep police?compound.dep three?nummod.dep found?obl.gov department?compound.gov said?advcl.gov
# 4	10	first?amod.dep like?case.dep really?advmod.dep says?ccomp.gov would?aux.dep think?ccomp.gov says?nsubj.gov one?nummod.dep one?nmod.gov back?advmod.dep never?advmod.dep last?amod.dep old?amod.dep could?aux.dep still?advmod.dep good?amod.dep even?advmod.dep best?amod.dep two?nummod.dep
#
# <900> LL/token: -11.51208
# <910> LL/token: -11.5137
# <920> LL/token: -11.51448
# <930> LL/token: -11.51332
# <940> LL/token: -11.51167
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep said?obl.gov president?nsubj.dep former?amod.dep american?amod.dep obama?flat.dep presidential?amod.dep also?advmod.dep white?amod.dep political?amod.dep john?flat.gov watch?obj.gov national?amod.dep
# 1	10	said?ccomp.gov said?nsubj.gov united?amod.dep two?nummod.dep president?flat.gov minister?amod.gov also?advmod.dep minister?flat.gov military?amod.dep international?amod.dep security?compound.dep states?amod.gov iraqi?amod.dep government?amod.gov last?amod.dep government?nsubj.dep officials?nsubj.dep said?obl.gov iraq?nmod.dep
# 2	10	new?amod.dep million?nummod.dep says?ccomp.gov says?nsubj.gov said?ccomp.gov also?advmod.dep said?nsubj.gov could?aux.dep would?aux.dep may?aux.dep even?advmod.dep people?nsubj.dep like?case.dep many?amod.dep one?nmod.gov billion?nummod.dep years?obl.dep one?nummod.dep high?amod.dep
# 3	10	said?ccomp.gov said?nsubj.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov two?nummod.dep police?nsubj.dep according?case.dep authorities?nsubj.dep also?advmod.dep watch?obj.gov three?nummod.dep could?aux.dep police?compound.dep said?obl.gov department?compound.gov found?obl.gov said?obl:tmod.gov
# 4	10	first?amod.dep like?case.dep says?ccomp.gov really?advmod.dep would?aux.dep one?nummod.dep still?advmod.dep last?amod.dep one?nmod.gov says?nsubj.gov back?advmod.dep never?advmod.dep think?ccomp.gov old?amod.dep also?advmod.dep best?amod.dep good?amod.dep two?nummod.dep time?amod.gov
#
# <950> LL/token: -11.51303
# <960> LL/token: -11.51189
# <970> LL/token: -11.51142
# <980> LL/token: -11.51302
# <990> LL/token: -11.51136
#
# 0	10	said?ccomp.gov said?nsubj.gov would?aux.dep president?flat.gov obama?nsubj.dep new?amod.dep democratic?amod.dep president?nsubj.dep said?obl.gov former?amod.dep american?amod.dep obama?flat.dep also?advmod.dep presidential?amod.dep political?amod.dep white?amod.dep watch?obj.gov john?flat.gov national?amod.dep
# 1	10	said?ccomp.gov said?nsubj.gov united?amod.dep two?nummod.dep also?advmod.dep minister?amod.gov minister?flat.gov military?amod.dep president?flat.gov security?compound.dep international?amod.dep states?amod.gov last?amod.dep iraqi?amod.dep government?amod.gov according?case.dep government?nsubj.dep said?obl.gov iraq?nmod.dep
# 2	10	new?amod.dep million?nummod.dep says?nsubj.gov said?ccomp.gov says?ccomp.gov also?advmod.dep may?aux.dep would?aux.dep could?aux.dep like?case.dep said?nsubj.gov one?nmod.gov many?amod.dep years?obl.dep billion?nummod.dep even?advmod.dep one?nummod.dep people?nsubj.dep make?obj.gov
# 3	10	said?nsubj.gov said?ccomp.gov said?parataxis.dep told?nsubj.gov told?ccomp.gov told?obj.gov police?nsubj.dep two?nummod.dep according?case.dep authorities?nsubj.dep watch?obj.gov could?aux.dep also?advmod.dep police?compound.dep three?nummod.dep said?obl.gov found?obl.gov said?obl:tmod.gov said?advcl.gov
# 4	10	first?amod.dep says?ccomp.gov like?case.dep really?advmod.dep would?aux.dep back?advmod.dep one?nummod.dep think?ccomp.gov one?nmod.gov says?nsubj.gov never?advmod.dep still?advmod.dep best?amod.dep old?amod.dep two?nummod.dep even?advmod.dep last?amod.dep good?amod.dep always?advmod.dep
#
# <1000> LL/token: -11.51101
#
# Total time: 1 minutes 31 seconds

# %%
# for coherence optimization
# plt.plot(range(5,31, 5), coherence_values)
# plt.xlabel("Num Topics")
# plt.ylabel("Coherence score")
# plt.show()

# %%
get_topics(model, 5)
# Out:
# {0: '0.009*"said?ccomp.gov" + 0.008*"said?nsubj.gov" + 0.006*"would?aux.dep" + 0.003*"president?flat.gov" + 0.003*"obama?nsubj.dep" + 0.002*"new?amod.dep" + 0.002*"democratic?amod.dep" + 0.002*"president?nsubj.dep" + 0.002*"former?amod.dep" + 0.002*"also?advmod.dep"',
#  1: '0.013*"said?ccomp.gov" + 0.012*"said?nsubj.gov" + 0.003*"united?amod.dep" + 0.003*"two?nummod.dep" + 0.002*"also?advmod.dep" + 0.002*"minister?amod.gov" + 0.002*"military?amod.dep" + 0.002*"minister?flat.gov" + 0.002*"states?amod.gov" + 0.002*"president?flat.gov"',
#  2: '0.003*"new?amod.dep" + 0.003*"million?nummod.dep" + 0.002*"says?nsubj.gov" + 0.002*"said?ccomp.gov" + 0.002*"also?advmod.dep" + 0.002*"says?ccomp.gov" + 0.002*"would?aux.dep" + 0.002*"may?aux.dep" + 0.002*"could?aux.dep" + 0.001*"like?case.dep"',
#  3: '0.019*"said?nsubj.gov" + 0.018*"said?ccomp.gov" + 0.004*"said?parataxis.dep" + 0.003*"told?nsubj.gov" + 0.003*"told?ccomp.gov" + 0.003*"told?obj.gov" + 0.003*"police?nsubj.dep" + 0.003*"two?nummod.dep" + 0.002*"according?case.dep" + 0.002*"authorities?nsubj.dep"',
#  4: '0.003*"first?amod.dep" + 0.003*"says?ccomp.gov" + 0.002*"like?case.dep" + 0.002*"really?advmod.dep" + 0.002*"would?aux.dep" + 0.002*"back?advmod.dep" + 0.002*"one?nummod.dep" + 0.002*"says?nsubj.gov" + 0.002*"one?nmod.gov" + 0.002*"think?ccomp.gov"'}

# %%
pickle.dump(model, open('models/naive_model.pkl', 'wb'))
